# %%
import PIL
dir(PIL)
# Out:
# ['UnidentifiedImageError',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_plugins',
#  '_raise_version_warning',
#  'sys',
#  'warnings']

# %%
from PIL import Image
help(PIL)
# Out:
# Help on package PIL:
#
# NAME
#     PIL - Pillow (Fork of the Python Imaging Library)
#
# DESCRIPTION
#     Pillow is the friendly PIL fork by Alex Clark and Contributors.
#         https://github.com/python-pillow/Pillow/
#
#     Pillow is forked from PIL 1.1.7.
#
#     PIL is the Python Imaging Library by Fredrik Lundh and Contributors.
#     Copyright (c) 1999 by Secret Labs AB.
#
#     Use PIL.__version__ for this Pillow version.
#
#     ;-)
#
# PACKAGE CONTENTS
#     BdfFontFile
#     BlpImagePlugin
#     BmpImagePlugin
#     BufrStubImagePlugin
#     ContainerIO
#     CurImagePlugin
#     DcxImagePlugin
#     DdsImagePlugin
#     EpsImagePlugin
#     ExifTags
#     FitsStubImagePlugin
#     FliImagePlugin
#     FontFile
#     FpxImagePlugin
#     FtexImagePlugin
#     GbrImagePlugin
#     GdImageFile
#     GifImagePlugin
#     GimpGradientFile
#     GimpPaletteFile
#     GribStubImagePlugin
#     Hdf5StubImagePlugin
#     IcnsImagePlugin
#     IcoImagePlugin
# ...

# %%
#chen them 'r' truoc duong dan hinh
file = r'C:\Users\A\Pictures\quacau.gif'
hinh = Image.open(file)
print(hinh)
# Out:
# <PIL.GifImagePlugin.GifImageFile image mode=P size=500x500 at 0x20871A18EC8>

# %%
from IPython.display import display
display(hinh)
# Out:
# <PIL.GifImagePlugin.GifImageFile image mode=P size=500x500 at 0x20871A18EC8>
